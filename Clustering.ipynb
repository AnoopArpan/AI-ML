# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
x,y=make_blobs(n_samples=1000,n_features=2,centers=1)

# %%
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
x.shape
# Out:
# (1000, 2)

# %%
x.size
# Out:
# 2000

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.cluster import KMeans

# %%
KMean=KMeans(n_clusters=3)

# %%
y_pred=KMean.fit(x_train)
# Out:
# C:\Users\Anoop Arpan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
y_pred
# Out:
# KMeans(n_clusters=3)

# %%
x_pred=KMean.predict(x_train)
x_pred
# Out:
# array([1, 2, 1, 0, 0, 2, 0, 2, 1, 1, 1, 0, 0, 1, 1, 2, 0, 2, 1, 1, 0, 2,
#        2, 1, 1, 0, 1, 1, 0, 0, 2, 2, 0, 2, 0, 1, 0, 0, 0, 0, 1, 1, 1, 0,
#        1, 0, 2, 2, 0, 2, 1, 0, 2, 2, 0, 1, 2, 0, 0, 2, 1, 1, 2, 0, 2, 2,
#        1, 2, 1, 2, 2, 2, 2, 1, 1, 1, 0, 2, 1, 0, 1, 0, 2, 2, 0, 1, 2, 1,
#        2, 2, 0, 0, 2, 2, 0, 2, 2, 2, 0, 1, 1, 2, 1, 2, 2, 1, 0, 0, 1, 1,
#        2, 0, 1, 2, 0, 2, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 2,
#        1, 1, 2, 2, 2, 0, 1, 2, 2, 1, 2, 1, 0, 2, 2, 1, 1, 0, 2, 0, 0, 1,
#        2, 2, 2, 2, 0, 1, 0, 1, 0, 2, 2, 2, 1, 1, 0, 0, 2, 0, 0, 0, 0, 0,
#        1, 1, 0, 0, 1, 2, 1, 0, 2, 1, 0, 1, 2, 1, 1, 1, 1, 2, 0, 0, 1, 0,
#        1, 0, 0, 0, 0, 2, 1, 2, 0, 1, 0, 1, 0, 2, 2, 0, 1, 1, 1, 0, 2, 2,
#        2, 2, 0, 1, 0, 1, 2, 0, 1, 1, 0, 1, 2, 0, 0, 1, 1, 2, 1, 0, 1, 1,
#        0, 2, 2, 2, 2, 2, 2, 0, 0, 1, 0, 2, 1, 2, 2, 1, 0, 0, 0, 0, 0, 0,
#        2, 2, 1, 1, 0, 0, 1, 2, 2, 0, 0, 2, 2, 2, 1, 0, 0, 0, 2, 2, 1, 0,
# ...

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=x_pred)
plt.show()

# %%
y_test.shape
# Out:
# (300,)

# %%
x_test_pred=KMean.predict(x_test)

# %%
plt.scatter(x_test[:,0],x_test[:,1],c=x_test_pred)
plt.show()
